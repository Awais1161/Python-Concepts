# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %%
# !pip install numba
# Out:
# Requirement already satisfied: numba in c:\users\awais\anaconda3\lib\site-packages (0.55.1)
# Requirement already satisfied: numpy<1.22,>=1.18 in c:\users\awais\anaconda3\lib\site-packages (from numba) (1.21.5)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\awais\anaconda3\lib\site-packages (from numba) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\awais\anaconda3\lib\site-packages (from numba) (61.2.0)

# %%
from numba import jit
import numpy as np
import time

# %%
x=np.arange(100).reshape(10,10)

@jit(nopython=True)
def go_fast(a):
    trace=0.0
    for i in range(a.shape[0]):
        trace +=np.tanh(a[i,i])
        return a + trace
    
start=time.time()
go_fast(x)
end=time.time()
print('Elapsed (with compilation) = %s' % (end-start))

start=time.time()
go_fast(x)
end=time.time()
print('Elapsed (after compilation) = %s' % (end-start))
# Out:
# Elapsed (with compilation) = 0.27505040168762207
# Elapsed (after compilation) = 0.0
